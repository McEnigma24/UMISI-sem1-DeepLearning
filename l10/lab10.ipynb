# %% [markdown]
# # Autoassociation network
# AKA *Autoassociative memory*

# %% [markdown]
# ### init

# %%
# Check for all needed packages
import time
import typing

import IPython
import matplotlib
import mnists
import numpy

# In case of ImportError, install them to the running kernel with
# %pip install numpy matplotlib mnists
# or in the runtime container with:
# !pip install numpy matplotlib mnists
# (In case of the latter, remember to restart the kernel!)

# Tested in Python 3.14.3 with:
# numpy==2.4.3
# matplotlib==3.10.8
# mnists==0.4.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

try:
    import mkl

    mkl.set_num_threads(2)
except ImportError:
    print(
        "Intel Math Kernel Library (MKL) does not always work on every machine. "
        "Continuing without `mkl`."
    )

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]
# Out:
# Intel Math Kernel Library (MKL) does not always work on every machine. Continuing without `mkl`.

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix: np.ndarray,  axis: int=1) -> np.ndarray:
    """
    Appends a column of ones to the right side of a 2D matrix.
    """
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of zeros with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. zeros(3, 4) creates a (3, 4) array.
    """
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of ones with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. ones(3, 4) creates a (3, 4) array.
    """
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a uniform [0, 1) distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a standard normal distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq: list, size: int) -> tuple[np.ndarray]:
    """
    Splits a sequence into consecutive chunks of a given size.

    The last chunk may be smaller than `size` if the sequence length
    is not evenly divisible.

    Args:
        seq:  The input sequence (e.g. list or other sliceable) to split.
        size: The maximum number of elements in each chunk.

    Returns:
        Successive sub-sequences of length `size` (or less for the final chunk).
    """
    return tuple([seq[pos : (pos + size)] for pos in range(0, len(seq), size)])


def as_matrix(vector: np.ndarray) -> np.ndarray:
    """Reshape 1D vector to column matrix."""
    return np.reshape(vector, (-1, 1))

def arrange_tiles_img(examples: np.ndarray) -> np.ndarray:
    """
    Arrange 2D matrices as tiles

    Takes 4D `examples` tensor with dims:
        rows x cols x tile_height x tile_width
    """
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = examples[r, c]

    return img_matrix


def preview_tiles(examples: np.ndarray) -> None:
    """Previews the arrange tiles"""
    img = arrange_tiles_img(examples)
    plt.matshow(img, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()

def draw_rbm_filters(rbm: "RestrictedBoltzmannMachine") -> None:
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    preview_tiles(filters)

def draw_layer_filters(layer: "Layer") -> None:
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    preview_tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch: np.ndarray) -> np.ndarray:
    s = sigmoid(batch)
    return s * (1.0 - s)

# %% [markdown]
# ![alt text](<Screenshot 2026-05-29 104509.png>)
# ![alt text](<Screenshot 2026-05-29 104503.png>)

# %%
# RBF Gaussian activation: f(x) = exp(-(x - mu)^2 / (2 * sigma^2)); mu=0, sigma=1.
def gaussian(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    mu = np.float32(0.0)
    sigma_sq = np.float32(1.0)
    activations = np.exp(-((batch - mu) ** 2) / (2.0 * sigma_sq)).astype(np.float32)
    if stochastic:
        return (activations > rand(*activations.shape).astype(np.float32)).astype(np.float32)
    return activations


def gaussian_derivative(batch: np.ndarray) -> np.ndarray:
    mu = np.float32(0.0)
    sigma_sq = np.float32(1.0)
    g = gaussian(batch, stochastic=False)
    return (g * (-(batch - mu) / sigma_sq)).astype(np.float32)

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]


def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], newshape=shape)


mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

preview_tiles(mnist_digits)

# %% [markdown]
# # RBM & DBN training

# %%
class RestrictedBoltzmannMachine:
    """
    A Restricted Boltzmann Machine (RBM) with a single visible and hidden layer.

    The weight matrix W has shape (visible_size + 1, hidden_size + 1), where
    the extra row and column are reserved for bias units.

    Attributes:
        visible_size:       Number of visible (input) units, excluding the bias.
        hidden_size:        Number of hidden units, excluding the bias.
        visible_act_func:   The activation function used within visible layer.
        hidden_act_func:    The activation function used within hidden layer.
        learning_rate:      Step size used during contrastive divergence updates.
        W:                  Weight matrix of shape (visible_size+1, hidden_size+1).
        momentum:           Momentum coefficient.
        l2_penalty:         Coefficent for the L2 regularization.
    """

    def __init__(
        self,
        visible_size: int,
        hidden_size: int,
        visible_act_func: callable,
        hidden_act_func: callable,
        learning_rate: float,
        momentum: float,
        l2_penalty: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.l2_penalty = l2_penalty

        self.reset()

    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0  # zero hidden-bias weights
        self.W[-1, :] = 0.0  # zero visible-bias weights
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
from typing import TypeAlias
DBN: TypeAlias = list[RestrictedBoltzmannMachine]

# %%
def cdk(rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray, k: int = 1) -> None:
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M

def reconstruction_error(
    rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray
) -> float:
    """
    Computes the mean per-sample reconstruction error on a minibatch.
    """
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))

    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))

    error = minibatch[:, :-1] - visible
    return np.sum(np.square(error)) / observations_count

# %%
def propagate_up(
    dbn: DBN,
    layers_count: int,
    visible: np.ndarray,
) -> np.ndarray:
    """
    Forward pass through DBN layers: propagates visible units upward to the target layer.
    Appends bias term (ones) and applies each RBM's **hidden** activation after v @ W[:, :-1].
    """
    for i in range(layers_count):
        visible = append_ones(dbn[i].hidden_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(
    dbn: DBN,
    layers_count: int,
    hidden: np.ndarray,
) -> np.ndarray:
    """
    Reconstruct data by propagating downward through the DBN.
    Appends bias term (ones) and applies each RBM's **visible** activation after h @ W[:-1, :].T.
    """
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].visible_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(
    dbn: DBN,
    layer_idx: int,
    minibatch: np.ndarray,
) -> float:
    """
    Compute the reconstruction error for a selected DBN layer.

    The minibatch is first propagated upward to the chosen layer,
    then the reconstruction error is evaluated for that RBM.

    Args:
        dbn: List of pretrained RBM layers.
        layer_idx: Index of the RBM layer to evaluate.
        minibatch: Input minibatch.

    Returns:
        Reconstruction error as a scalar value.
    """
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstruction_error(dbn[layer_idx], propagated)



def train_dbn_layer(
    dbn: DBN,
    layer_idx: int,
    dataset: np.ndarray,
    batch_size: int,
) -> None:
    """
    Train one DBN layer using greedy layer-wise pretraining.

    The dataset is first propagated through all previously trained layers.
    Then the selected RBM layer is trained on minibatches.

    Args:
        dbn: List of RBM layers.
        layer_idx: Index of the RBM layer to train.
        dataset: Full training dataset.
        batch_size: Minibatch size.
    """

    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

def run_dbn_training(
    dbn: DBN,
    dataset: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
    target_momentum: float = 0.9,
) -> None:
    for layer_idx in range(len(dbn)):
        print(f"\nLearning layer {layer_idx}")

        for epoch in range(epochs_count):
            print(f"Epoch {epoch}:", end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print(f"\telapsed: {elapsed:>2.2f}s, reconstruction error: {error:>2.2f}")

# %% [markdown]
# # Autoencoder training

# %% [markdown]
# ### begin

# %%
from typing import Callable

class Layer:
    def __init__(
        self,
        visible_size: int,
        hidden_size: int,
        activation_fun: Callable[..., np.ndarray],
        d_activation_fun: Callable[[np.ndarray], np.ndarray],
        learning_rate: float,
        momentum: float,
        l2_penalty: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.l2_penalty = l2_penalty

        self.reset()

    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0 # biases

        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %%
from typing import TypeAlias
MLP: TypeAlias = list[Layer]

# %%
def forward_pass(ae: MLP, batch: np.ndarray, compute_derivatives: bool) -> np.ndarray:
    visible = batch

    for layer_idx, layer in enumerate(ae):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))

        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)

        visible = layer.activations

    return visible[:, :-1]

def error_backpropagate(ae: MLP, batch: np.ndarray) -> None:
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch

        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)

        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]

        layer.W += layer.M

# %% [markdown]
# ### Cross entropy cost

# %% [markdown]
# Implement [cross entropy](https://en.wikipedia.org/wiki/Cross-entropy#Cross-entropy_minimization) cost for deep AE. To this end:
# * calculate the cross entropy cost between pixels in the input batch and their reconstructions,
# * sum the cross entropy cost over all pixels and all observations in the minibatch,
# * return average cost per input observation.
#
# In other words, for each sample in batch, we are trying to implement:
# $$
# H(p,q) = - \sum_m{p_{m} \log{q_m}}
# $$
# where $H(p,q)$ is the cross-entropy of the distribution $q$ relative to a distribition $p$ over a given set, where distributions $p \in \{y, 1-y\}$ and $q \in \{ \hat{y}, 1 - \hat{y} \}$ consist of $y$, which is an orignal sample from Mnist, and $\hat{y}$, which is a reconstruction.

# %%
def xentropy(batch: np.ndarray, reconstructions: np.ndarray) -> np.ndarray:
    observations_count = batch.shape[0]
    eps = np.float32(1e-7)
    r = np.clip(reconstructions.astype(np.float32), eps, np.float32(1.0) - eps)
    b = batch.astype(np.float32)
    ce = -(b * np.log(r) + (np.float32(1.0) - b) * np.log(np.float32(1.0) - r))
    return np.array(np.sum(ce) / observations_count, dtype=np.float32)

# %% [markdown]
# ### Training procedure

# %%
def train_ae(
    ae: MLP, dataset: np.ndarray, batch_size: np.ndarray
) -> None:
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)

    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)

        observations_count = batch.shape[0]
        targets = batch[:, :-1].astype(np.float32)
        ae[-1].deltas = ((reconstructions.astype(np.float32) - targets) / observations_count).astype(np.float32)

        error_backpropagate(ae, batch)

        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(
    ae: MLP,
    train_set: np.ndarray,
    validation_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for epoch in range(epochs_count):
        print(f"Epoch {epoch + 1}:", end="\t")

        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print(f"\telapsed: {elapsed:>2.2f}s, cross-entropy: {xe:>2.2f}")

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights
#
# Implement initialization of AE weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the AE weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_ae_from_dbn(ae: MLP, dbn: DBN) -> None:
    assert len(ae) == 2 * len(dbn)

    n = len(dbn)
    # One DBN layer k -> encoder slot k (bottom-up) and decoder slot (2n-1-k) (top-down).
    for k, rbm in enumerate(dbn):
        enc_idx = k
        dec_idx = 2 * n - 1 - k

        ae[enc_idx].W = rbm.W[:, :-1].astype(np.float32).copy()
        ae[enc_idx].M = zeros(rbm.visible_size + 1, rbm.hidden_size)

        ae[dec_idx].W = (rbm.W.T)[:, :-1].astype(np.float32).copy()
        ae[dec_idx].M = zeros(rbm.hidden_size + 1, rbm.visible_size)

# %% [markdown]
# # Autoencoder for MNIST digits

# %% [markdown]
# ### first

# %%
np.random.seed(1234)

DATASET_SIZE: int = 10000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE: int = DIGIT_SIZE * DIGIT_SIZE

BATCH_SIZE: int = 128
EPOCHS_COUNT: int = 50

RBM_LEARNING_RATE: float = 0.1
AE_LEARNING_RATE: float = 0.01
AE_MOMENTUM: float = 0.9
L2_PENALTY: float = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(
    ae: MLP,
    dbn: DBN,
    train_set: np.ndarray,
    validation_set: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for layer in ae:
        layer.reset()

    display(HTML('<h3>Plain AE training</h3>'))
    run_ae_training(
        ae=ae,
        train_set=train_set,
        validation_set=validation_set,
        batch_size=batch_size,
        epochs_count=epochs_count
    )

    display(HTML('<h3>Input layer filters in the plain AE</h3>'))
    draw_layer_filters(ae[0])

    display(HTML('<h3>Input minibatch</h3>'))
    preview_tiles(np.reshape(validation_set[:8*24, :-1], newshape=(8, 24, 28, 28)))

    display(HTML('<h3>Plain AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False), newshape=(8, 24, 28, 28))
    preview_tiles(ae_reconstructions)

    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(
        dbn=dbn,
        dataset=train_set,
        monitoring_set=monitoring_set,
        batch_size=batch_size,
        epochs_count=epochs_count
    )

    for layer in ae:
        layer.reset()

    initialize_ae_from_dbn(ae=ae, dbn=dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False), newshape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(
        batch=validation_set[:, :-1],
        reconstructions=forward_pass(ae, validation_set, False)
    )

    display(HTML('<h3>Finetuning pretrained AE</h3>'))

    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(
        ae=ae,
        train_set=train_set,
        validation_set=validation_set,
        batch_size=batch_size,
        epochs_count=epochs_count
    )

    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])

    display(HTML('<h3>Input layer filters in the pretrained & finetuned AE</h3>'))
    draw_layer_filters(ae[0])

    display(HTML('<h3>Input minibatch</h3>'))
    preview_tiles(np.reshape(validation_set[:8*24, :-1], newshape=(8, 24, 28, 28)))

    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    preview_tiles(dbn_reconstructions)

    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False), newshape=(8, 24, 28, 28))
    preview_tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    RestrictedBoltzmannMachine(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    RestrictedBoltzmannMachine(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    RestrictedBoltzmannMachine(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    RestrictedBoltzmannMachine(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae: MLP = [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE / 10.0, 0.5, L2_PENALTY),
    Layer(10, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
]

compare_results(
    ae=ae,
    dbn=dbn,
    train_set=mnist_train_images,
    validation_set=mnist_test_images,
    monitoring_set=monitoring_set,
    batch_size=BATCH_SIZE,
    epochs_count=EPOCHS_COUNT,
)
# Out:
# <h3>Plain AE training</h3>
# Epoch 1:	########################################	elapsed: 3.77s, cross-entropy: 453.91
# Epoch 2:	########################################	elapsed: 2.27s, cross-entropy: 385.94
# Epoch 3:	########################################	elapsed: 2.20s, cross-entropy: 336.67
# Epoch 4:	########################################	elapsed: 4.32s, cross-entropy: 301.71
# Epoch 5:	########################################	elapsed: 12.93s, cross-entropy: 277.39
# Epoch 6:	########################################	elapsed: 5.61s, cross-entropy: 260.56
# Epoch 7:	########################################	elapsed: 6.00s, cross-entropy: 248.81
# Epoch 8:	########################################	elapsed: 7.25s, cross-entropy: 240.46
# Epoch 9:	########################################	elapsed: 4.76s, cross-entropy: 234.37
# Epoch 10:	########################################	elapsed: 3.73s, cross-entropy: 229.83
# Epoch 11:	########################################	elapsed: 2.52s, cross-entropy: 226.37
# Epoch 12:	########################################	elapsed: 3.64s, cross-entropy: 223.66
# Epoch 13:	########################################	elapsed: 2.29s, cross-entropy: 221.50
# Epoch 14:	########################################	elapsed: 4.01s, cross-entropy: 219.75
# Epoch 15:	########################################	elapsed: 7.05s, cross-entropy: 218.31
# Epoch 16:	########################################	elapsed: 4.11s, cross-entropy: 217.11
# Epoch 17:	########################################	elapsed: 3.16s, cross-entropy: 216.09
# Epoch 18:	########################################	elapsed: 2.61s, cross-entropy: 215.23
# Epoch 19:	########################################	elapsed: 1.99s, cross-entropy: 214.49
# Epoch 20:	########################################	elapsed: 1.87s, cross-entropy: 213.84
# Epoch 21:	########################################	elapsed: 3.18s, cross-entropy: 213.28
# Epoch 22:	########################################	elapsed: 2.01s, cross-entropy: 212.78
# Epoch 23:	########################################	elapsed: 1.92s, cross-entropy: 212.34
# Epoch 24:	########################################	elapsed: 2.49s, cross-entropy: 211.95
# Epoch 25:	########################################	elapsed: 1.86s, cross-entropy: 211.60
# Epoch 26:	########################################	elapsed: 1.88s, cross-entropy: 211.29
# Epoch 27:	########################################	elapsed: 1.82s, cross-entropy: 211.00
# Epoch 28:	########################################	elapsed: 2.35s, cross-entropy: 210.74
# Epoch 29:	########################################	elapsed: 2.00s, cross-entropy: 210.51
# Epoch 30:	########################################	elapsed: 2.38s, cross-entropy: 210.29
# Epoch 31:	########################################	elapsed: 2.15s, cross-entropy: 210.09
# Epoch 32:	########################################	elapsed: 2.68s, cross-entropy: 209.91
# Epoch 33:	########################################	elapsed: 4.73s, cross-entropy: 209.75
# Epoch 34:	########################################	elapsed: 2.80s, cross-entropy: 209.59
# Epoch 35:	########################################	elapsed: 2.74s, cross-entropy: 209.45
# Epoch 36:	########################################	elapsed: 2.36s, cross-entropy: 209.32
# Epoch 37:	########################################	elapsed: 2.25s, cross-entropy: 209.19
# Epoch 38:	########################################	elapsed: 1.82s, cross-entropy: 209.08
# Epoch 39:	########################################	elapsed: 2.42s, cross-entropy: 208.97
# Epoch 40:	########################################	elapsed: 2.26s, cross-entropy: 208.87
# Epoch 41:	########################################	elapsed: 2.11s, cross-entropy: 208.77
# Epoch 42:	########################################	elapsed: 3.56s, cross-entropy: 208.68
# Epoch 43:	########################################	elapsed: 0.95s, cross-entropy: 208.60
# Epoch 44:	########################################	elapsed: 0.91s, cross-entropy: 208.52
# Epoch 45:	########################################	elapsed: 0.90s, cross-entropy: 208.45
# Epoch 46:	########################################	elapsed: 1.07s, cross-entropy: 208.37
# Epoch 47:	########################################	elapsed: 0.87s, cross-entropy: 208.31
# Epoch 48:	########################################	elapsed: 0.74s, cross-entropy: 208.24
# Epoch 49:	########################################	elapsed: 0.89s, cross-entropy: 208.18
# Epoch 50:	########################################	elapsed: 0.69s, cross-entropy: 208.13
# Training finished!
# <h3>Input layer filters in the plain AE</h3>
# <h3>Input minibatch</h3>
# <h3>Plain AE reconstructions</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 0:	########################################	elapsed: 0.58s, reconstruction error: 31.66
# Epoch 1:	########################################	elapsed: 0.55s, reconstruction error: 24.76
# Epoch 2:	########################################	elapsed: 0.48s, reconstruction error: 21.29
# Epoch 3:	########################################	elapsed: 0.68s, reconstruction error: 19.00
# Epoch 4:	########################################	elapsed: 0.49s, reconstruction error: 17.64
# Epoch 5:	########################################	elapsed: 0.48s, reconstruction error: 15.24
# Epoch 6:	########################################	elapsed: 0.50s, reconstruction error: 13.77
# Epoch 7:	########################################	elapsed: 0.50s, reconstruction error: 12.63
# Epoch 8:	########################################	elapsed: 0.63s, reconstruction error: 12.05
# Epoch 9:	########################################	elapsed: 0.63s, reconstruction error: 11.58
# Epoch 10:	########################################	elapsed: 0.61s, reconstruction error: 11.05
# Epoch 11:	########################################	elapsed: 1.32s, reconstruction error: 10.83
# Epoch 12:	########################################	elapsed: 0.58s, reconstruction error: 10.68
# Epoch 13:	########################################	elapsed: 0.80s, reconstruction error: 10.54
# Epoch 14:	########################################	elapsed: 0.69s, reconstruction error: 10.42
# Epoch 15:	########################################	elapsed: 0.89s, reconstruction error: 10.15
# Epoch 16:	########################################	elapsed: 0.90s, reconstruction error: 10.08
# Epoch 17:	########################################	elapsed: 0.69s, reconstruction error: 10.04
# Epoch 18:	########################################	elapsed: 0.51s, reconstruction error: 9.80
# Epoch 19:	########################################	elapsed: 0.60s, reconstruction error: 9.89
# Epoch 20:	########################################	elapsed: 0.64s, reconstruction error: 9.71
# Epoch 21:	########################################	elapsed: 0.53s, reconstruction error: 9.61
# Epoch 22:	########################################	elapsed: 0.50s, reconstruction error: 9.62
# Epoch 23:	########################################	elapsed: 0.52s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 0.83s, reconstruction error: 9.38
# Epoch 25:	########################################	elapsed: 0.99s, reconstruction error: 9.33
# Epoch 26:	########################################	elapsed: 0.53s, reconstruction error: 9.24
# Epoch 27:	########################################	elapsed: 0.41s, reconstruction error: 9.36
# Epoch 28:	########################################	elapsed: 0.49s, reconstruction error: 9.15
# Epoch 29:	########################################	elapsed: 0.46s, reconstruction error: 9.28
# Epoch 30:	########################################	elapsed: 0.48s, reconstruction error: 9.20
# Epoch 31:	########################################	elapsed: 0.47s, reconstruction error: 8.96
# Epoch 32:	########################################	elapsed: 0.46s, reconstruction error: 9.04
# Epoch 33:	########################################	elapsed: 0.47s, reconstruction error: 9.09
# Epoch 34:	########################################	elapsed: 0.42s, reconstruction error: 9.03
# Epoch 35:	########################################	elapsed: 0.46s, reconstruction error: 8.87
# Epoch 36:	########################################	elapsed: 0.44s, reconstruction error: 8.95
# Epoch 37:	########################################	elapsed: 0.39s, reconstruction error: 8.87
# Epoch 38:	########################################	elapsed: 0.42s, reconstruction error: 8.84
# Epoch 39:	########################################	elapsed: 0.45s, reconstruction error: 8.88
# Epoch 40:	########################################	elapsed: 0.46s, reconstruction error: 8.82
# Epoch 41:	########################################	elapsed: 0.44s, reconstruction error: 8.77
# Epoch 42:	########################################	elapsed: 0.42s, reconstruction error: 8.68
# Epoch 43:	########################################	elapsed: 0.43s, reconstruction error: 8.87
# Epoch 44:	########################################	elapsed: 0.46s, reconstruction error: 8.79
# Epoch 45:	########################################	elapsed: 0.45s, reconstruction error: 8.70
# Epoch 46:	########################################	elapsed: 0.49s, reconstruction error: 8.79
# Epoch 47:	########################################	elapsed: 0.42s, reconstruction error: 8.76
# Epoch 48:	########################################	elapsed: 0.40s, reconstruction error: 8.64
# Epoch 49:	########################################	elapsed: 0.44s, reconstruction error: 8.66
#
# Learning layer 1
# Epoch 0:	########################################	elapsed: 0.26s, reconstruction error: 20.89
# Epoch 1:	########################################	elapsed: 0.21s, reconstruction error: 15.82
# Epoch 2:	########################################	elapsed: 0.24s, reconstruction error: 13.74
# Epoch 3:	########################################	elapsed: 0.23s, reconstruction error: 12.38
# Epoch 4:	########################################	elapsed: 0.24s, reconstruction error: 11.45
# Epoch 5:	########################################	elapsed: 0.26s, reconstruction error: 9.42
# Epoch 6:	########################################	elapsed: 0.22s, reconstruction error: 8.22
# Epoch 7:	########################################	elapsed: 0.21s, reconstruction error: 7.54
# Epoch 8:	########################################	elapsed: 0.24s, reconstruction error: 7.13
# Epoch 9:	########################################	elapsed: 0.24s, reconstruction error: 6.91
# Epoch 10:	########################################	elapsed: 0.27s, reconstruction error: 6.64
# Epoch 11:	########################################	elapsed: 0.34s, reconstruction error: 6.39
# Epoch 12:	########################################	elapsed: 0.30s, reconstruction error: 6.33
# Epoch 13:	########################################	elapsed: 0.31s, reconstruction error: 6.23
# Epoch 14:	########################################	elapsed: 0.34s, reconstruction error: 6.02
# Epoch 15:	########################################	elapsed: 0.37s, reconstruction error: 5.92
# Epoch 16:	########################################	elapsed: 0.31s, reconstruction error: 6.00
# Epoch 17:	########################################	elapsed: 0.67s, reconstruction error: 5.97
# Epoch 18:	########################################	elapsed: 0.33s, reconstruction error: 5.77
# Epoch 19:	########################################	elapsed: 0.33s, reconstruction error: 5.76
# Epoch 20:	########################################	elapsed: 0.28s, reconstruction error: 5.66
# Epoch 21:	########################################	elapsed: 0.47s, reconstruction error: 5.66
# Epoch 22:	########################################	elapsed: 0.41s, reconstruction error: 5.57
# Epoch 23:	########################################	elapsed: 0.43s, reconstruction error: 5.58
# Epoch 24:	########################################	elapsed: 0.25s, reconstruction error: 5.52
# Epoch 25:	########################################	elapsed: 0.23s, reconstruction error: 5.64
# Epoch 26:	########################################	elapsed: 0.21s, reconstruction error: 5.49
# Epoch 27:	########################################	elapsed: 0.24s, reconstruction error: 5.36
# Epoch 28:	########################################	elapsed: 0.23s, reconstruction error: 5.44
# Epoch 29:	########################################	elapsed: 0.27s, reconstruction error: 5.39
# Epoch 30:	########################################	elapsed: 0.24s, reconstruction error: 5.47
# Epoch 31:	########################################	elapsed: 0.27s, reconstruction error: 5.44
# Epoch 32:	########################################	elapsed: 0.24s, reconstruction error: 5.39
# Epoch 33:	########################################	elapsed: 0.26s, reconstruction error: 5.21
# Epoch 34:	########################################	elapsed: 0.23s, reconstruction error: 5.26
# Epoch 35:	########################################	elapsed: 0.22s, reconstruction error: 5.28
# Epoch 36:	########################################	elapsed: 0.23s, reconstruction error: 5.20
# Epoch 37:	########################################	elapsed: 0.24s, reconstruction error: 5.17
# Epoch 38:	########################################	elapsed: 0.31s, reconstruction error: 5.23
# Epoch 39:	########################################	elapsed: 0.25s, reconstruction error: 5.17
# Epoch 40:	########################################	elapsed: 0.24s, reconstruction error: 5.19
# Epoch 41:	########################################	elapsed: 0.21s, reconstruction error: 5.22
# Epoch 42:	########################################	elapsed: 0.23s, reconstruction error: 5.14
# Epoch 43:	########################################	elapsed: 0.22s, reconstruction error: 5.09
# Epoch 44:	########################################	elapsed: 0.24s, reconstruction error: 5.05
# Epoch 45:	########################################	elapsed: 0.23s, reconstruction error: 5.03
# Epoch 46:	########################################	elapsed: 0.27s, reconstruction error: 5.08
# Epoch 47:	########################################	elapsed: 0.29s, reconstruction error: 5.05
# Epoch 48:	########################################	elapsed: 0.22s, reconstruction error: 5.10
# Epoch 49:	########################################	elapsed: 0.23s, reconstruction error: 5.07
#
# Learning layer 2
# Epoch 0:	########################################	elapsed: 0.21s, reconstruction error: 14.37
# Epoch 1:	########################################	elapsed: 0.21s, reconstruction error: 10.59
# Epoch 2:	########################################	elapsed: 0.18s, reconstruction error: 9.30
# Epoch 3:	########################################	elapsed: 0.18s, reconstruction error: 8.28
# Epoch 4:	########################################	elapsed: 0.16s, reconstruction error: 7.67
# Epoch 5:	########################################	elapsed: 0.18s, reconstruction error: 6.36
# Epoch 6:	########################################	elapsed: 0.18s, reconstruction error: 5.57
# Epoch 7:	########################################	elapsed: 0.18s, reconstruction error: 5.24
# Epoch 8:	########################################	elapsed: 0.19s, reconstruction error: 4.95
# Epoch 9:	########################################	elapsed: 0.17s, reconstruction error: 4.81
# Epoch 10:	########################################	elapsed: 0.15s, reconstruction error: 4.55
# Epoch 11:	########################################	elapsed: 0.18s, reconstruction error: 4.59
# Epoch 12:	########################################	elapsed: 0.17s, reconstruction error: 4.42
# Epoch 13:	########################################	elapsed: 0.22s, reconstruction error: 4.42
# Epoch 14:	########################################	elapsed: 0.21s, reconstruction error: 4.34
# Epoch 15:	########################################	elapsed: 0.17s, reconstruction error: 4.35
# Epoch 16:	########################################	elapsed: 0.17s, reconstruction error: 4.28
# Epoch 17:	########################################	elapsed: 0.19s, reconstruction error: 4.25
# Epoch 18:	########################################	elapsed: 0.20s, reconstruction error: 4.22
# Epoch 19:	########################################	elapsed: 0.19s, reconstruction error: 4.17
# Epoch 20:	########################################	elapsed: 0.16s, reconstruction error: 4.15
# Epoch 21:	########################################	elapsed: 0.18s, reconstruction error: 4.15
# Epoch 22:	########################################	elapsed: 0.19s, reconstruction error: 4.09
# Epoch 23:	########################################	elapsed: 0.20s, reconstruction error: 4.12
# Epoch 24:	########################################	elapsed: 0.17s, reconstruction error: 4.14
# Epoch 25:	########################################	elapsed: 0.19s, reconstruction error: 4.06
# Epoch 26:	########################################	elapsed: 0.20s, reconstruction error: 4.07
# Epoch 27:	########################################	elapsed: 0.17s, reconstruction error: 4.03
# Epoch 28:	########################################	elapsed: 0.21s, reconstruction error: 4.08
# Epoch 29:	########################################	elapsed: 0.25s, reconstruction error: 4.00
# Epoch 30:	########################################	elapsed: 0.19s, reconstruction error: 4.07
# Epoch 31:	########################################	elapsed: 0.19s, reconstruction error: 3.96
# Epoch 32:	########################################	elapsed: 0.17s, reconstruction error: 3.97
# Epoch 33:	########################################	elapsed: 0.18s, reconstruction error: 4.02
# Epoch 34:	########################################	elapsed: 0.18s, reconstruction error: 4.00
# Epoch 35:	########################################	elapsed: 0.18s, reconstruction error: 4.01
# Epoch 36:	########################################	elapsed: 0.19s, reconstruction error: 4.01
# Epoch 37:	########################################	elapsed: 0.34s, reconstruction error: 3.95
# Epoch 38:	########################################	elapsed: 0.30s, reconstruction error: 3.88
# Epoch 39:	########################################	elapsed: 0.22s, reconstruction error: 3.96
# Epoch 40:	########################################	elapsed: 0.17s, reconstruction error: 3.99
# Epoch 41:	########################################	elapsed: 0.18s, reconstruction error: 3.97
# Epoch 42:	########################################	elapsed: 0.18s, reconstruction error: 3.96
# Epoch 43:	########################################	elapsed: 0.19s, reconstruction error: 3.92
# Epoch 44:	########################################	elapsed: 0.21s, reconstruction error: 3.93
# Epoch 45:	########################################	elapsed: 0.22s, reconstruction error: 3.85
# Epoch 46:	########################################	elapsed: 0.17s, reconstruction error: 3.92
# Epoch 47:	########################################	elapsed: 0.16s, reconstruction error: 3.90
# Epoch 48:	########################################	elapsed: 0.18s, reconstruction error: 3.86
# Epoch 49:	########################################	elapsed: 0.22s, reconstruction error: 3.94
#
# Learning layer 3
# Epoch 0:	########################################	elapsed: 0.11s, reconstruction error: 10.03
# Epoch 1:	########################################	elapsed: 0.10s, reconstruction error: 9.89
# Epoch 2:	########################################	elapsed: 0.11s, reconstruction error: 9.75
# Epoch 3:	########################################	elapsed: 0.08s, reconstruction error: 9.55
# Epoch 4:	########################################	elapsed: 0.09s, reconstruction error: 9.33
# Epoch 5:	########################################	elapsed: 0.10s, reconstruction error: 8.90
# Epoch 6:	########################################	elapsed: 0.09s, reconstruction error: 8.91
# Epoch 7:	########################################	elapsed: 0.10s, reconstruction error: 8.94
# Epoch 8:	########################################	elapsed: 0.08s, reconstruction error: 9.00
# Epoch 9:	########################################	elapsed: 0.10s, reconstruction error: 9.19
# Epoch 10:	########################################	elapsed: 0.08s, reconstruction error: 9.23
# Epoch 11:	########################################	elapsed: 0.09s, reconstruction error: 9.37
# Epoch 12:	########################################	elapsed: 0.11s, reconstruction error: 9.41
# Epoch 13:	########################################	elapsed: 0.09s, reconstruction error: 9.54
# Epoch 14:	########################################	elapsed: 0.10s, reconstruction error: 9.65
# Epoch 15:	########################################	elapsed: 0.09s, reconstruction error: 9.70
# Epoch 16:	########################################	elapsed: 0.10s, reconstruction error: 9.82
# Epoch 17:	########################################	elapsed: 0.09s, reconstruction error: 9.87
# Epoch 18:	########################################	elapsed: 0.10s, reconstruction error: 9.91
# Epoch 19:	########################################	elapsed: 0.09s, reconstruction error: 10.03
# Epoch 20:	########################################	elapsed: 0.10s, reconstruction error: 10.10
# Epoch 21:	########################################	elapsed: 0.08s, reconstruction error: 10.08
# Epoch 22:	########################################	elapsed: 0.09s, reconstruction error: 10.18
# Epoch 23:	########################################	elapsed: 0.09s, reconstruction error: 10.27
# Epoch 24:	########################################	elapsed: 0.08s, reconstruction error: 10.29
# Epoch 25:	########################################	elapsed: 0.10s, reconstruction error: 10.38
# Epoch 26:	########################################	elapsed: 0.08s, reconstruction error: 10.39
# Epoch 27:	########################################	elapsed: 0.08s, reconstruction error: 10.45
# Epoch 28:	########################################	elapsed: 0.09s, reconstruction error: 10.59
# Epoch 29:	########################################	elapsed: 0.08s, reconstruction error: 10.58
# Epoch 30:	########################################	elapsed: 0.08s, reconstruction error: 10.72
# Epoch 31:	########################################	elapsed: 0.09s, reconstruction error: 10.72
# Epoch 32:	########################################	elapsed: 0.10s, reconstruction error: 10.77
# Epoch 33:	########################################	elapsed: 0.10s, reconstruction error: 10.74
# Epoch 34:	########################################	elapsed: 0.08s, reconstruction error: 10.89
# Epoch 35:	########################################	elapsed: 0.09s, reconstruction error: 10.86
# Epoch 36:	########################################	elapsed: 0.09s, reconstruction error: 10.89
# Epoch 37:	########################################	elapsed: 0.08s, reconstruction error: 10.87
# Epoch 38:	########################################	elapsed: 0.09s, reconstruction error: 10.96
# Epoch 39:	########################################	elapsed: 0.09s, reconstruction error: 10.98
# Epoch 40:	########################################	elapsed: 0.09s, reconstruction error: 10.98
# Epoch 41:	########################################	elapsed: 0.09s, reconstruction error: 11.07
# Epoch 42:	########################################	elapsed: 0.10s, reconstruction error: 11.11
# Epoch 43:	########################################	elapsed: 0.10s, reconstruction error: 11.08
# Epoch 44:	########################################	elapsed: 0.09s, reconstruction error: 11.13
# Epoch 45:	########################################	elapsed: 0.10s, reconstruction error: 11.06
# Epoch 46:	########################################	elapsed: 0.11s, reconstruction error: 11.13
# Epoch 47:	########################################	elapsed: 0.10s, reconstruction error: 11.12
# Epoch 48:	########################################	elapsed: 0.09s, reconstruction error: 11.14
# Epoch 49:	########################################	elapsed: 0.09s, reconstruction error: 11.21
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 376.22
#
# Epoch 1:	########################################	elapsed: 0.77s, cross-entropy: 337.67
# Epoch 2:	########################################	elapsed: 0.91s, cross-entropy: 310.02
# Epoch 3:	########################################	elapsed: 0.84s, cross-entropy: 290.79
# Epoch 4:	########################################	elapsed: 0.88s, cross-entropy: 276.97
# Epoch 5:	########################################	elapsed: 0.77s, cross-entropy: 266.61
# Epoch 6:	########################################	elapsed: 0.77s, cross-entropy: 258.55
# Epoch 7:	########################################	elapsed: 1.00s, cross-entropy: 252.07
# Epoch 8:	########################################	elapsed: 2.63s, cross-entropy: 246.75
# Epoch 9:	########################################	elapsed: 1.34s, cross-entropy: 242.29
# Epoch 10:	########################################	elapsed: 0.79s, cross-entropy: 238.50
# Epoch 11:	########################################	elapsed: 0.85s, cross-entropy: 235.23
# Epoch 12:	########################################	elapsed: 0.99s, cross-entropy: 232.37
# Epoch 13:	########################################	elapsed: 0.76s, cross-entropy: 229.84
# Epoch 14:	########################################	elapsed: 0.86s, cross-entropy: 227.58
# Epoch 15:	########################################	elapsed: 0.74s, cross-entropy: 225.55
# Epoch 16:	########################################	elapsed: 0.97s, cross-entropy: 223.70
# Epoch 17:	########################################	elapsed: 0.75s, cross-entropy: 222.00
# Epoch 18:	########################################	elapsed: 0.78s, cross-entropy: 220.45
# Epoch 19:	########################################	elapsed: 0.88s, cross-entropy: 219.01
# Epoch 20:	########################################	elapsed: 0.78s, cross-entropy: 217.68
# Epoch 21:	########################################	elapsed: 0.73s, cross-entropy: 216.44
# Epoch 22:	########################################	elapsed: 0.81s, cross-entropy: 215.28
# Epoch 23:	########################################	elapsed: 0.78s, cross-entropy: 214.20
# Epoch 24:	########################################	elapsed: 0.91s, cross-entropy: 213.18
# Epoch 25:	########################################	elapsed: 0.72s, cross-entropy: 212.22
# Epoch 26:	########################################	elapsed: 0.78s, cross-entropy: 211.32
# Epoch 27:	########################################	elapsed: 0.79s, cross-entropy: 210.47
# Epoch 28:	########################################	elapsed: 0.83s, cross-entropy: 209.66
# Epoch 29:	########################################	elapsed: 0.85s, cross-entropy: 208.90
# Epoch 30:	########################################	elapsed: 0.76s, cross-entropy: 208.17
# Epoch 31:	########################################	elapsed: 0.75s, cross-entropy: 207.48
# Epoch 32:	########################################	elapsed: 0.80s, cross-entropy: 206.82
# Epoch 33:	########################################	elapsed: 0.77s, cross-entropy: 206.20
# Epoch 34:	########################################	elapsed: 0.86s, cross-entropy: 205.59
# Epoch 35:	########################################	elapsed: 0.82s, cross-entropy: 205.02
# Epoch 36:	########################################	elapsed: 0.84s, cross-entropy: 204.46
# Epoch 37:	########################################	elapsed: 0.75s, cross-entropy: 203.93
# Epoch 38:	########################################	elapsed: 0.75s, cross-entropy: 203.42
# Epoch 39:	########################################	elapsed: 0.86s, cross-entropy: 202.93
# Epoch 40:	########################################	elapsed: 1.02s, cross-entropy: 202.46
# Epoch 41:	########################################	elapsed: 0.75s, cross-entropy: 202.01
# Epoch 42:	########################################	elapsed: 0.74s, cross-entropy: 201.58
# Epoch 43:	########################################	elapsed: 0.70s, cross-entropy: 201.16
# Epoch 44:	########################################	elapsed: 0.81s, cross-entropy: 200.75
# Epoch 45:	########################################	elapsed: 0.85s, cross-entropy: 200.36
# Epoch 46:	########################################	elapsed: 0.73s, cross-entropy: 199.98
# Epoch 47:	########################################	elapsed: 0.78s, cross-entropy: 199.62
# Epoch 48:	########################################	elapsed: 0.83s, cross-entropy: 199.26
# Epoch 49:	########################################	elapsed: 0.79s, cross-entropy: 198.92
# Epoch 50:	########################################	elapsed: 0.76s, cross-entropy: 198.58
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned AE</h3>
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>

# %% [markdown]
# ## Additional materials
# * [Medium | Why do we use cross entropy in logistic regresion? A statistical view | Likelihood & log-likelihood](https://medium.com/@haythamahmed2001/why-do-we-use-cross-entropy-in-logistic-regression-a-statistical-view-4414ea95c72b)
