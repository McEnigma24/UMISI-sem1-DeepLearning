# %% [markdown]
# # ReLU Activation Function. Vector Weights Norm Regularization.

# %%
# Check for all needed packages
import time

import IPython
import matplotlib
import mnists
import numpy

# In case of ImportError, install them to the running kernel with
# %pip install numpy matplotlib mnists
# or the the runtime container with:
# !pip install numpy matplotlib mnists
# (In case of the latter, remember to restart the kernel!)

# Tested in Python 3.14.3 with:
# numpy==2.4.3
# matplotlib==3.10.8
# mnists==0.4.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

try:
    import mkl

    mkl.set_num_threads(2)
except ImportError:
    print(
        "Intel Math Kernel Library (MKL) does not always work on every machine. "
        "Continuing without `mkl`."
    )

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]
# Out:
# Intel Math Kernel Library (MKL) does not always work on every machine. Continuing without `mkl`.

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix: np.ndarray,  axis: int=1) -> np.ndarray:
    """
    Appends a column of ones to the right side of a 2D matrix.
    """
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of zeros with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. zeros(3, 4) creates a (3, 4) array.
    """
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of ones with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. ones(3, 4) creates a (3, 4) array.
    """
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a uniform [0, 1) distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a standard normal distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq: list, size: int) -> tuple[np.ndarray]:
    """
    Splits a sequence into consecutive chunks of a given size.

    The last chunk may be smaller than `size` if the sequence length
    is not evenly divisible.

    Args:
        seq:  The input sequence (e.g. list or other sliceable) to split.
        size: The maximum number of elements in each chunk.

    Returns:
        Successive sub-sequences of length `size` (or less for the final chunk).
    """
    return tuple([seq[pos : (pos + size)] for pos in range(0, len(seq), size)])


def as_matrix(vector: np.ndarray) -> np.ndarray:
    """Reshape 1D vector to column matrix."""
    return np.reshape(vector, (-1, 1))


def one_hot_encode(labels: np.ndarray) -> np.ndarray:
    """Convert integer labels to one-hot encoded matrix."""
    (n_samples,) = labels.shape
    n_classes = np.max(labels) + 1

    one_hot = np.zeros((n_samples, n_classes), dtype=np.float32)
    one_hot[np.arange(n_samples), labels] = 1
    return one_hot

def classify(mlp: "MLP", batch: np.ndarray, forwad_pass_func: callable) -> np.ndarray:
    """
    Classify a batch of inputs using the MLP model.

    Performs a forward pass to compute class probabilities, then returns
    the predicted class indices (argmax over probabilities).

    Args:
        mlp: Trained MLP model with forward_pass method.
        batch: Input data batch of shape (N, input_dim).

    Returns:
        Predicted class indices of shape (N,).
    """
    # Shape: (batch_size, num_classes)
    probabilities: np.ndarray = forwad_pass_func(mlp, batch, False)

    predictions = np.argmax(probabilities, axis=1)
    return predictions

def arrange_tiles_img(examples: np.ndarray) -> np.ndarray:
    """
    Arrange 2D matrices as tiles

    Takes 4D `examples` tensor with dims:
        rows x cols x tile_height x tile_width
    """
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = examples[r, c]

    return img_matrix


def preview_tiles(examples: np.ndarray) -> None:
    """Previews the arrange tiles"""
    img = arrange_tiles_img(examples)
    plt.matshow(img, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()

def draw_rbm_filters(rbm: "RestrictedBoltzmannMachine") -> None:
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    preview_tiles(filters)

def draw_layer_filters(layer: "Layer") -> None:
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    preview_tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch: np.ndarray) -> np.ndarray:
    x = as_matrix(batch) if batch.ndim == 1 else batch
    max_in_each_row = np.max(x, axis=1, keepdims=True)
    e = np.exp(x - max_in_each_row)
    sum_in_each_row = np.sum(e, axis=1, keepdims=True)
    return e / sum_in_each_row

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]


def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], newshape=shape)


mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

preview_tiles(mnist_digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %% [markdown]
# Stochastic ReLU: $ f(z) = z \cdot \mathbb{1}_{z>0} + \epsilon $
#
# Standard: $ f(z) = \max(0, z) $
#
# Stochastic: $ f(z) = z + \mathcal{N}(0, \sigma(z)) $
#
# where $ \sigma(z) = \sqrt{sigmoid(z)} $
#
#
#
# ReLU derivative: $ f'(z) = \mathbb{1}_{z>0} $

# %%
def relu(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    """
    Stochastic ReLU
    """
    clamped = np.maximum(0, batch)
    if stochastic:
        sigma = np.sqrt(sigmoid(clamped))
        clamped += sigma * randn(*batch.shape)

    return clamped

def relu_derivative(batch: np.ndarray) -> np.ndarray:
    """
    ReLU derivative: 1 where z > 0, else 0 (element-wise, same shape as batch).
    """
    return (batch > 0).astype(np.float32)

# %% [markdown]
# Weight normalization: $ W_{norm} = W / \max(1, ||W_{:,j}||/\lambda) $
#
# Ensures $ ||W_{norm_{:,j}}||_2 \leq \lambda $ for each column $ j $

# %%
def limit_weights(weights: np.ndarray, lambda_limit: float) -> np.ndarray:
    """
    Max-norm: ogranicza normę L2 każdej kolumny wag (wejścia do jednego neuronu) do lambda_limit.
    """
    norms = np.linalg.norm(weights, axis=0, keepdims=True).astype(np.float32)
    scale = np.minimum(
        np.float32(1.0),
        np.float32(lambda_limit) / (norms + np.float32(1e-12)),
    )
    return (weights * scale).astype(np.float32)

# %% [markdown]
# # RBM & DBN training

# %%
class RestrictedBoltzmannMachine:
    """
    A Restricted Boltzmann Machine (RBM) with a single visible and hidden layer.

    The weight matrix W has shape (visible_size + 1, hidden_size + 1), where
    the extra row and column are reserved for bias units.

    Attributes:
        visible_size:       Number of visible (input) units, excluding the bias.
        hidden_size:        Number of hidden units, excluding the bias.
        visible_act_func:   The activation function used within visible layer.
        hidden_act_func:    The activation function used within hidden layer.
        learning_rate:      Step size used during contrastive divergence updates.
        W:                  Weight matrix of shape (visible_size+1, hidden_size+1).
        momentum:           Momentum coefficient.
        weight_limit:       Weight limit normalization coefficient.
    """

    def __init__(
        self,
        visible_size: int,
        hidden_size: int,
        visible_act_func: callable,
        hidden_act_func: callable,
        learning_rate: float,
        momentum: float,
        weight_limit: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.weight_limit = weight_limit

        self.reset()

    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0  # zero hidden-bias weights
        self.W[-1, :] = 0.0  # zero visible-bias weights
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
from typing import TypeAlias
DBN: TypeAlias = list[RestrictedBoltzmannMachine]

# %%
def cdk(rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray, k: int = 1) -> None:
    """Contrastive divergence using this RBM's visible/hidden activations.

    Matches the Bernoulli-RBM CD from lab5-7 when both activations are sigmoid
    (mean-field positive/negative hidden, sampled chain otherwise). For ReLU RBMs,
    the same structure uses ``stochastic=False`` for mean activations and
    ``stochastic=True`` where the sigmoid formulation sampled Bernoulli states.
    """
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    positive_hidden[:, :-1] = rbm.hidden_act_func(
        minibatch @ rbm.W[:, :-1], stochastic=False
    )
    negative_hidden[:, :-1] = rbm.hidden_act_func(
        minibatch @ rbm.W[:, :-1], stochastic=True
    )

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(
            negative_hidden @ np.transpose(rbm.W[:-1, :]), stochastic=True
        )

        pre_h = negative_visible @ rbm.W[:, :-1]
        negative_hidden[:, :-1] = rbm.hidden_act_func(pre_h, stochastic=False)
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(pre_h, stochastic=True)

    rbm.M = (
        rbm.momentum * rbm.M
        + (rbm.learning_rate / observations_count)
        * (np.transpose(positive_visible) @ positive_hidden)
        - (rbm.learning_rate / observations_count)
        * (np.transpose(negative_visible) @ negative_hidden)
    )

    rbm.W = rbm.W + rbm.M

def reconstruction_error(
    rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray
) -> float:
    """
    Computes the mean per-sample reconstruction error on a minibatch.
    """

    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))

    error = minibatch[:, :-1] - visible
    return np.sum(np.square(error)) / observations_count

# %%
def propagate_up(
    dbn: DBN,
    layers_count: int,
    visible: np.ndarray,
) -> np.ndarray:
    """
    Forward pass through DBN layers: propagates visible units upward to the target layer.
    Appends bias term (ones) and applies each layer's hidden activation (deterministic).
    """
    for i in range(layers_count):
        visible = append_ones(
            dbn[i].hidden_act_func(visible @ dbn[i].W[:, :-1], stochastic=False)
        )
    return visible


def propagate_down(
    dbn: DBN,
    layers_count: int,
    hidden: np.ndarray,
) -> np.ndarray:
    """
    Reconstruct data by propagating downward through the DBN.
    Appends bias term (ones) and applies each layer's visible activation (deterministic).
    """
    for i in reversed(range(layers_count)):
        hidden = append_ones(
            dbn[i].visible_act_func(
                hidden @ np.transpose(dbn[i].W[:-1, :]), stochastic=False
            )
        )
    return hidden

def dbn_reconstuction_error(
    dbn: DBN,
    layer_idx: int,
    minibatch: np.ndarray,
) -> float:
    """
    Compute the reconstruction error for a selected DBN layer.

    The minibatch is first propagated upward to the chosen layer,
    then the reconstruction error is evaluated for that RBM.

    Args:
        dbn: List of pretrained RBM layers.
        layer_idx: Index of the RBM layer to evaluate.
        minibatch: Input minibatch.

    Returns:
        Reconstruction error as a scalar value.
    """
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstruction_error(dbn[layer_idx], propagated)

    return error

def train_dbn_layer(
    dbn: DBN,
    layer_idx: int,
    dataset: np.ndarray,
    batch_size: int,
) -> None:
    """
    Train one DBN layer using greedy layer-wise pretraining.

    The dataset is first propagated through all previously trained layers.
    Then the selected RBM layer is trained on minibatches.

    Args:
        dbn: List of RBM layers.
        layer_idx: Index of the RBM layer to train.
        dataset: Full training dataset.
        batch_size: Minibatch size.
    """

    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

def run_dbn_training(
    dbn: DBN,
    dataset: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
    target_momentum: float = 0.9,
) -> None:
    for layer_idx in range(len(dbn)):
        print(f"\nLearning layer {layer_idx}")

        for epoch in range(epochs_count):
            print(f"Epoch {epoch}:", end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print(f"\telapsed: {elapsed:>2.2f}s, reconstruction error: {error:>2.2f}")

# %% [markdown]
# # MLP training

# %%
from typing import Callable


class Layer:
    def __init__(
        self,
        visible_size: int,
        hidden_size: int,
        activation_fun: Callable[[np.ndarray], np.ndarray],
        d_activation_fun: Callable[[np.ndarray], np.ndarray],
        learning_rate: float,
        momentum: float,
        weight_limit: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.weight_limit = weight_limit

        self.reset()

    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0

        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %%
from typing import TypeAlias
MLP: TypeAlias = list[Layer]

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp: MLP, batch: np.ndarray, compute_derivatives: bool) -> np.ndarray:
    visible = batch

    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))

        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)

        visible = layer.activations

    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp: MLP, batch: np.ndarray) -> None:
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            prev_layer.deltas = (layer.deltas @ layer.W.T)[:, :-1] * prev_layer.d_activations
        else:
            visible = batch

        grad = visible.T @ layer.deltas / observations_count
        layer.M = layer.momentum * layer.M - layer.learning_rate * grad
        layer.W += layer.M

        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(
    mlp: MLP, dataset: np.ndarray, labels: np.ndarray, batch_size: np.ndarray
) -> None:
    batches_limit = dataset.shape[0] / batch_size

    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)

    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)

        mlp[-1].deltas = y - batch_labels

        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)

        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(
    mlp: MLP,
    train_set: np.ndarray,
    train_labels: np.ndarray,
    validation_set: np.ndarray,
    validation_labels: np.ndarray,
    batch_size: int,
    epochs_count: int,
    forward_pass_func: callable,
    target_momentum: float = 0.95,
) -> None:
    for epoch in range(epochs_count):
        print(f"Epoch {epoch + 1}:", end="\t")

        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum

        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set, forward_pass_func)
        accuracy = (
            100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        )
        print(f"\telapsed: {elapsed:>2.2f}s, accuracy: {accuracy:>2.2f}")
    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp_from_dbn(mlp: MLP, dbn: DBN) -> None:
    # Protip for better encpaulsation: create a helper class for MLP, with a custom constructor (@classmethod), `from_dbn(dbn: DBN)`

    for i in range(len(dbn)):
        mlp[i].W[:] = np.copy(dbn[i].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE: int = 10000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE: int = DIGIT_SIZE * DIGIT_SIZE
HIDDEN_LAYER_SIZE: int = 256

BATCH_SIZE: int = 128
EPOCHS_COUNT: int = 50

MLP_LEARNING_RATE: float = 0.03
SOFTMAX_LEARNING_RATE: float = 0.15
RBM_LEARNING_RATE: float = 0.003
MOMENTUM: float = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML


def compare_pretraining_results(
    mlp: MLP,
    dbn: DBN,
    train_set: np.ndarray,
    train_labels: np.ndarray,
    validation_set: np.ndarray,
    validation_labels: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for layer in mlp:
        layer.reset()

    display(HTML("<h3>Plain MLP training</h3>"))
    run_mlp_training(
        mlp=mlp,
        train_set=train_set,
        train_labels=train_labels,
        validation_set=validation_set,
        validation_labels=validation_labels,
        batch_size=batch_size,
        epochs_count=epochs_count,
        forward_pass_func=forward_pass,
    )

    display(HTML("<h3>Input layer filters in the plain MLP</h3>"))
    draw_layer_filters(mlp[0])

    display(HTML("<h3>DBN training</h3>"))
    run_dbn_training(
        dbn=dbn,
        dataset=train_set,
        monitoring_set=monitoring_set,
        batch_size=batch_size,
        epochs_count=epochs_count,
    )

    for layer in mlp:
        layer.reset()

    initialize_mlp_from_dbn(mlp, dbn)

    display(HTML("<h3>Finetuning pretrained MLP</h3>"))
    run_mlp_training(
        mlp=mlp,
        train_set=train_set,
        train_labels=train_labels,
        validation_set=validation_set,
        validation_labels=validation_labels,
        batch_size=batch_size,
        epochs_count=epochs_count,
        forward_pass_func=forward_pass,
    )

    display(HTML("<h3>First layer filters in the DBN</h3>"))
    draw_rbm_filters(dbn[0])

    display(HTML("<h3>Input layer filters in the pretrained & finetuned MLP</h3>"))
    draw_layer_filters(mlp[0])

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(
        visible_size=VISIBLE_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=2.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=10,
        activation_fun=softmax,
        d_activation_fun=None,
        learning_rate=SOFTMAX_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=4.0,
    ),
]

shallow_dbn = [
    RestrictedBoltzmannMachine(
        visible_size=VISIBLE_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        visible_act_func=sigmoid,
        hidden_act_func=relu,
        learning_rate=RBM_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=2.0,
    ),
    RestrictedBoltzmannMachine(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        visible_act_func=relu,
        hidden_act_func=relu,
        learning_rate=RBM_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    )
]

compare_pretraining_results(
    mlp=shallow_mlp,
    dbn=shallow_dbn,
    train_set=mnist_train_images,
    train_labels=mnist_train_labels,
    validation_set=mnist_test_images,
    validation_labels=mnist_test_labels,
    monitoring_set=monitoring_set,
    batch_size=BATCH_SIZE,
    epochs_count=EPOCHS_COUNT,
)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.41s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.29s, accuracy: 31.54
# Epoch 3:	########################################	elapsed: 0.31s, accuracy: 65.26
# Epoch 4:	########################################	elapsed: 0.31s, accuracy: 74.15
# Epoch 5:	########################################	elapsed: 0.28s, accuracy: 80.37
# Epoch 6:	########################################	elapsed: 0.24s, accuracy: 89.79
# Epoch 7:	########################################	elapsed: 0.26s, accuracy: 92.34
# Epoch 8:	########################################	elapsed: 0.28s, accuracy: 93.00
# Epoch 9:	########################################	elapsed: 0.25s, accuracy: 93.98
# Epoch 10:	########################################	elapsed: 0.21s, accuracy: 94.79
# Epoch 11:	########################################	elapsed: 0.21s, accuracy: 93.99
# Epoch 12:	########################################	elapsed: 0.25s, accuracy: 94.83
# Epoch 13:	########################################	elapsed: 0.20s, accuracy: 93.59
# Epoch 14:	########################################	elapsed: 0.24s, accuracy: 94.12
# Epoch 15:	########################################	elapsed: 0.40s, accuracy: 95.61
# Epoch 16:	########################################	elapsed: 0.30s, accuracy: 95.39
# Epoch 17:	########################################	elapsed: 0.33s, accuracy: 95.58
# Epoch 18:	########################################	elapsed: 0.39s, accuracy: 95.88
# Epoch 19:	########################################	elapsed: 0.41s, accuracy: 95.93
# Epoch 20:	########################################	elapsed: 0.35s, accuracy: 96.06
# Epoch 21:	########################################	elapsed: 0.35s, accuracy: 95.49
# Epoch 22:	########################################	elapsed: 0.32s, accuracy: 96.08
# Epoch 23:	########################################	elapsed: 0.37s, accuracy: 96.44
# Epoch 24:	########################################	elapsed: 0.65s, accuracy: 96.55
# Epoch 25:	########################################	elapsed: 0.45s, accuracy: 96.59
# Epoch 26:	########################################	elapsed: 0.33s, accuracy: 96.67
# Epoch 27:	########################################	elapsed: 0.31s, accuracy: 96.66
# Epoch 28:	########################################	elapsed: 0.31s, accuracy: 96.66
# Epoch 29:	########################################	elapsed: 0.34s, accuracy: 96.66
# Epoch 30:	########################################	elapsed: 0.34s, accuracy: 96.66
# Epoch 31:	########################################	elapsed: 0.28s, accuracy: 96.66
# Epoch 32:	########################################	elapsed: 0.28s, accuracy: 96.64
# Epoch 33:	########################################	elapsed: 0.29s, accuracy: 96.64
# Epoch 34:	########################################	elapsed: 0.28s, accuracy: 96.65
# Epoch 35:	########################################	elapsed: 0.65s, accuracy: 96.66
# Epoch 36:	########################################	elapsed: 0.28s, accuracy: 96.66
# Epoch 37:	########################################	elapsed: 0.30s, accuracy: 96.66
# Epoch 38:	########################################	elapsed: 0.29s, accuracy: 96.65
# Epoch 39:	########################################	elapsed: 0.29s, accuracy: 96.63
# Epoch 40:	########################################	elapsed: 0.28s, accuracy: 96.64
# Epoch 41:	########################################	elapsed: 0.28s, accuracy: 96.64
# Epoch 42:	########################################	elapsed: 0.27s, accuracy: 96.65
# Epoch 43:	########################################	elapsed: 0.28s, accuracy: 96.65
# Epoch 44:	########################################	elapsed: 0.33s, accuracy: 96.65
# Epoch 45:	########################################	elapsed: 0.29s, accuracy: 96.66
# Epoch 46:	########################################	elapsed: 0.26s, accuracy: 96.65
# Epoch 47:	########################################	elapsed: 0.26s, accuracy: 96.64
# Epoch 48:	########################################	elapsed: 0.25s, accuracy: 96.64
# Epoch 49:	########################################	elapsed: 0.27s, accuracy: 96.65
# Epoch 50:	########################################	elapsed: 0.28s, accuracy: 96.64
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 0:	########################################	elapsed: 0.77s, reconstruction error: 79.18
# Epoch 1:	########################################	elapsed: 0.43s, reconstruction error: 56.52
# Epoch 2:	########################################	elapsed: 0.50s, reconstruction error: 44.40
# Epoch 3:	########################################	elapsed: 0.46s, reconstruction error: 37.73
# Epoch 4:	########################################	elapsed: 0.47s, reconstruction error: 33.99
# Epoch 5:	########################################	elapsed: 0.52s, reconstruction error: 26.55
# Epoch 6:	########################################	elapsed: 0.50s, reconstruction error: 22.58
# Epoch 7:	########################################	elapsed: 0.46s, reconstruction error: 20.42
# Epoch 8:	########################################	elapsed: 0.50s, reconstruction error: 18.99
# Epoch 9:	########################################	elapsed: 0.46s, reconstruction error: 18.00
# Epoch 10:	########################################	elapsed: 0.45s, reconstruction error: 17.27
# Epoch 11:	########################################	elapsed: 0.47s, reconstruction error: 16.54
# Epoch 12:	########################################	elapsed: 0.44s, reconstruction error: 16.17
# Epoch 13:	########################################	elapsed: 0.46s, reconstruction error: 15.40
# Epoch 14:	########################################	elapsed: 0.48s, reconstruction error: 14.98
# Epoch 15:	########################################	elapsed: 0.46s, reconstruction error: 14.53
# Epoch 16:	########################################	elapsed: 0.60s, reconstruction error: 14.49
# Epoch 17:	########################################	elapsed: 0.46s, reconstruction error: 13.92
# Epoch 18:	########################################	elapsed: 0.48s, reconstruction error: 13.75
# Epoch 19:	########################################	elapsed: 0.49s, reconstruction error: 13.51
# Epoch 20:	########################################	elapsed: 0.51s, reconstruction error: 13.29
# Epoch 21:	########################################	elapsed: 0.48s, reconstruction error: 12.76
# Epoch 22:	########################################	elapsed: 0.49s, reconstruction error: 12.72
# Epoch 23:	########################################	elapsed: 0.49s, reconstruction error: 12.69
# Epoch 24:	########################################	elapsed: 0.49s, reconstruction error: 12.63
# Epoch 25:	########################################	elapsed: 0.50s, reconstruction error: 12.42
# Epoch 26:	########################################	elapsed: 0.53s, reconstruction error: 12.45
# Epoch 27:	########################################	elapsed: 0.52s, reconstruction error: 12.17
# Epoch 28:	########################################	elapsed: 0.62s, reconstruction error: 12.15
# Epoch 29:	########################################	elapsed: 0.56s, reconstruction error: 12.05
# Epoch 30:	########################################	elapsed: 0.50s, reconstruction error: 12.04
# Epoch 31:	########################################	elapsed: 0.46s, reconstruction error: 12.05
# Epoch 32:	########################################	elapsed: 0.58s, reconstruction error: 11.82
# Epoch 33:	########################################	elapsed: 0.51s, reconstruction error: 11.95
# Epoch 34:	########################################	elapsed: 0.69s, reconstruction error: 11.90
# Epoch 35:	########################################	elapsed: 0.65s, reconstruction error: 12.19
# Epoch 36:	########################################	elapsed: 0.96s, reconstruction error: 11.86
# Epoch 37:	########################################	elapsed: 0.80s, reconstruction error: 11.84
# Epoch 38:	########################################	elapsed: 0.61s, reconstruction error: 11.75
# Epoch 39:	########################################	elapsed: 0.64s, reconstruction error: 11.63
# Epoch 40:	########################################	elapsed: 0.77s, reconstruction error: 11.49
# Epoch 41:	########################################	elapsed: 0.72s, reconstruction error: 11.77
# Epoch 42:	########################################	elapsed: 1.06s, reconstruction error: 11.54
# Epoch 43:	########################################	elapsed: 0.69s, reconstruction error: 11.61
# Epoch 44:	########################################	elapsed: 0.60s, reconstruction error: 11.79
# Epoch 45:	########################################	elapsed: 0.55s, reconstruction error: 11.69
# Epoch 46:	########################################	elapsed: 0.56s, reconstruction error: 11.83
# Epoch 47:	########################################	elapsed: 0.53s, reconstruction error: 11.78
# Epoch 48:	########################################	elapsed: 0.53s, reconstruction error: 11.64
# Epoch 49:	########################################	elapsed: 0.49s, reconstruction error: 11.53
#
# Learning layer 1
# Epoch 0:	########################################	elapsed: 0.33s, reconstruction error: 110.29
# Epoch 1:	########################################	elapsed: 0.33s, reconstruction error: 79.94
# Epoch 2:	########################################	elapsed: 0.34s, reconstruction error: 66.79
# Epoch 3:	########################################	elapsed: 0.53s, reconstruction error: 59.84
# Epoch 4:	########################################	elapsed: 0.42s, reconstruction error: 55.39
# Epoch 5:	########################################	elapsed: 0.39s, reconstruction error: 59.86
# Epoch 6:	########################################	elapsed: 0.36s, reconstruction error: 59.32
# Epoch 7:	########################################	elapsed: 0.36s, reconstruction error: 61.20
# Epoch 8:	########################################	elapsed: 0.35s, reconstruction error: 63.71
# Epoch 9:	########################################	elapsed: 0.35s, reconstruction error: 63.27
# Epoch 10:	########################################	elapsed: 0.36s, reconstruction error: 62.94
# Epoch 11:	########################################	elapsed: 0.34s, reconstruction error: 63.71
# Epoch 12:	########################################	elapsed: 0.35s, reconstruction error: 64.35
# Epoch 13:	########################################	elapsed: 0.35s, reconstruction error: 64.72
# Epoch 14:	########################################	elapsed: 0.34s, reconstruction error: 66.04
# Epoch 15:	########################################	elapsed: 0.36s, reconstruction error: 66.79
# Epoch 16:	########################################	elapsed: 0.34s, reconstruction error: 67.97
# Epoch 17:	########################################	elapsed: 0.36s, reconstruction error: 68.35
# Epoch 18:	########################################	elapsed: 0.34s, reconstruction error: 67.63
# Epoch 19:	########################################	elapsed: 0.35s, reconstruction error: 68.69
# Epoch 20:	########################################	elapsed: 0.34s, reconstruction error: 70.68
# Epoch 21:	########################################	elapsed: 0.34s, reconstruction error: 69.69
# Epoch 22:	########################################	elapsed: 0.35s, reconstruction error: 71.60
# Epoch 23:	########################################	elapsed: 0.33s, reconstruction error: 71.56
# Epoch 24:	########################################	elapsed: 0.33s, reconstruction error: 73.20
# Epoch 25:	########################################	elapsed: 0.34s, reconstruction error: 74.65
# Epoch 26:	########################################	elapsed: 0.33s, reconstruction error: 75.37
# Epoch 27:	########################################	elapsed: 0.35s, reconstruction error: 75.87
# Epoch 28:	########################################	elapsed: 0.34s, reconstruction error: 77.21
# Epoch 29:	########################################	elapsed: 0.34s, reconstruction error: 76.79
# Epoch 30:	########################################	elapsed: 0.34s, reconstruction error: 77.66
# Epoch 31:	########################################	elapsed: 0.33s, reconstruction error: 79.83
# Epoch 32:	########################################	elapsed: 0.34s, reconstruction error: 81.32
# Epoch 33:	########################################	elapsed: 0.40s, reconstruction error: 80.08
# Epoch 34:	########################################	elapsed: 0.33s, reconstruction error: 83.51
# Epoch 35:	########################################	elapsed: 0.34s, reconstruction error: 82.10
# Epoch 36:	########################################	elapsed: 0.34s, reconstruction error: 84.07
# Epoch 37:	########################################	elapsed: 0.59s, reconstruction error: 82.11
# Epoch 38:	########################################	elapsed: 0.34s, reconstruction error: 84.52
# Epoch 39:	########################################	elapsed: 0.38s, reconstruction error: 85.44
# Epoch 40:	########################################	elapsed: 0.45s, reconstruction error: 85.25
# Epoch 41:	########################################	elapsed: 0.36s, reconstruction error: 87.61
# Epoch 42:	########################################	elapsed: 0.36s, reconstruction error: 86.50
# Epoch 43:	########################################	elapsed: 0.34s, reconstruction error: 87.09
# Epoch 44:	########################################	elapsed: 0.34s, reconstruction error: 87.96
# Epoch 45:	########################################	elapsed: 0.35s, reconstruction error: 88.73
# Epoch 46:	########################################	elapsed: 0.36s, reconstruction error: 90.70
# Epoch 47:	########################################	elapsed: 0.37s, reconstruction error: 90.16
# Epoch 48:	########################################	elapsed: 0.34s, reconstruction error: 93.00
# Epoch 49:	########################################	elapsed: 0.34s, reconstruction error: 91.20
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.28s, accuracy: 95.13
# Epoch 2:	########################################	elapsed: 0.25s, accuracy: 96.09
# Epoch 3:	########################################	elapsed: 0.23s, accuracy: 96.41
# Epoch 4:	########################################	elapsed: 0.24s, accuracy: 96.67
# Epoch 5:	########################################	elapsed: 0.26s, accuracy: 97.09
# Epoch 6:	########################################	elapsed: 0.24s, accuracy: 96.91
# Epoch 7:	########################################	elapsed: 0.25s, accuracy: 97.10
# Epoch 8:	########################################	elapsed: 0.23s, accuracy: 97.19
# Epoch 9:	########################################	elapsed: 0.23s, accuracy: 97.19
# Epoch 10:	########################################	elapsed: 0.25s, accuracy: 97.21
# Epoch 11:	########################################	elapsed: 0.25s, accuracy: 97.32
# Epoch 12:	########################################	elapsed: 0.25s, accuracy: 97.32
# Epoch 13:	########################################	elapsed: 0.28s, accuracy: 97.29
# Epoch 14:	########################################	elapsed: 0.30s, accuracy: 97.36
# Epoch 15:	########################################	elapsed: 0.33s, accuracy: 97.37
# Epoch 16:	########################################	elapsed: 0.27s, accuracy: 97.38
# Epoch 17:	########################################	elapsed: 0.29s, accuracy: 97.39
# Epoch 18:	########################################	elapsed: 0.25s, accuracy: 97.38
# Epoch 19:	########################################	elapsed: 0.25s, accuracy: 97.40
# Epoch 20:	########################################	elapsed: 0.27s, accuracy: 97.40
# Epoch 21:	########################################	elapsed: 0.25s, accuracy: 97.39
# Epoch 22:	########################################	elapsed: 0.41s, accuracy: 97.39
# Epoch 23:	########################################	elapsed: 0.39s, accuracy: 97.38
# Epoch 24:	########################################	elapsed: 0.32s, accuracy: 97.37
# Epoch 25:	########################################	elapsed: 0.32s, accuracy: 97.38
# Epoch 26:	########################################	elapsed: 0.29s, accuracy: 97.37
# Epoch 27:	########################################	elapsed: 0.27s, accuracy: 97.37
# Epoch 28:	########################################	elapsed: 0.29s, accuracy: 97.38
# Epoch 29:	########################################	elapsed: 0.32s, accuracy: 97.39
# Epoch 30:	########################################	elapsed: 0.30s, accuracy: 97.38
# Epoch 31:	########################################	elapsed: 0.51s, accuracy: 97.40
# Epoch 32:	########################################	elapsed: 0.25s, accuracy: 97.39
# Epoch 33:	########################################	elapsed: 0.25s, accuracy: 97.42
# Epoch 34:	########################################	elapsed: 0.25s, accuracy: 97.41
# Epoch 35:	########################################	elapsed: 0.29s, accuracy: 97.42
# Epoch 36:	########################################	elapsed: 0.26s, accuracy: 97.42
# Epoch 37:	########################################	elapsed: 0.26s, accuracy: 97.42
# Epoch 38:	########################################	elapsed: 0.26s, accuracy: 97.41
# Epoch 39:	########################################	elapsed: 0.27s, accuracy: 97.41
# Epoch 40:	########################################	elapsed: 0.25s, accuracy: 97.40
# Epoch 41:	########################################	elapsed: 0.26s, accuracy: 97.39
# Epoch 42:	########################################	elapsed: 0.24s, accuracy: 97.38
# Epoch 43:	########################################	elapsed: 0.27s, accuracy: 97.37
# Epoch 44:	########################################	elapsed: 0.38s, accuracy: 97.38
# Epoch 45:	########################################	elapsed: 0.35s, accuracy: 97.39
# Epoch 46:	########################################	elapsed: 0.25s, accuracy: 97.39
# Epoch 47:	########################################	elapsed: 0.25s, accuracy: 97.39
# Epoch 48:	########################################	elapsed: 0.27s, accuracy: 97.39
# Epoch 49:	########################################	elapsed: 0.24s, accuracy: 97.40
# Epoch 50:	########################################	elapsed: 0.26s, accuracy: 97.40
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(
        visible_size=VISIBLE_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=2.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=2 * HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    ),
    Layer(
        visible_size=2 * HIDDEN_LAYER_SIZE,
        hidden_size=10,
        activation_fun=softmax,
        d_activation_fun=None,
        learning_rate=SOFTMAX_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=4.0,
    ),
]

deep_dbn = [
    RestrictedBoltzmannMachine(
        visible_size=VISIBLE_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        visible_act_func=sigmoid,
        hidden_act_func=relu,
        learning_rate=RBM_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=2.0,
    ),
    RestrictedBoltzmannMachine(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        visible_act_func=relu,
        hidden_act_func=relu,
        learning_rate=RBM_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    ),
    RestrictedBoltzmannMachine(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=2 * HIDDEN_LAYER_SIZE,
        visible_act_func=relu,
        hidden_act_func=relu,
        learning_rate=RBM_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    )
]

compare_pretraining_results(
    mlp=deep_mlp,
    dbn=deep_dbn,
    train_set=mnist_train_images,
    train_labels=mnist_train_labels,
    validation_set=mnist_test_images,
    validation_labels=mnist_test_labels,
    monitoring_set=monitoring_set,
    batch_size=BATCH_SIZE,
    epochs_count=EPOCHS_COUNT,
)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.48s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.45s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 0.56s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 0.61s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 0.80s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.51s, accuracy: 38.88
# Epoch 7:	########################################	elapsed: 0.48s, accuracy: 78.77
# Epoch 8:	########################################	elapsed: 0.39s, accuracy: 88.40
# Epoch 9:	########################################	elapsed: 0.48s, accuracy: 92.08
# Epoch 10:	########################################	elapsed: 0.42s, accuracy: 93.20
# Epoch 11:	########################################	elapsed: 0.42s, accuracy: 93.77
# Epoch 12:	########################################	elapsed: 0.63s, accuracy: 93.96
# Epoch 13:	########################################	elapsed: 0.66s, accuracy: 92.89
# Epoch 14:	########################################	elapsed: 0.54s, accuracy: 93.30
# Epoch 15:	########################################	elapsed: 0.50s, accuracy: 94.19
# Epoch 16:	########################################	elapsed: 0.48s, accuracy: 93.61
# Epoch 17:	########################################	elapsed: 0.55s, accuracy: 95.31
# Epoch 18:	########################################	elapsed: 0.45s, accuracy: 95.00
# Epoch 19:	########################################	elapsed: 0.44s, accuracy: 95.62
# Epoch 20:	########################################	elapsed: 0.46s, accuracy: 94.85
# Epoch 21:	########################################	elapsed: 0.43s, accuracy: 95.38
# Epoch 22:	########################################	elapsed: 0.51s, accuracy: 95.77
# Epoch 23:	########################################	elapsed: 0.45s, accuracy: 95.63
# Epoch 24:	########################################	elapsed: 0.47s, accuracy: 95.08
# Epoch 25:	########################################	elapsed: 0.53s, accuracy: 95.80
# Epoch 26:	########################################	elapsed: 0.49s, accuracy: 95.79
# Epoch 27:	########################################	elapsed: 0.47s, accuracy: 96.44
# Epoch 28:	########################################	elapsed: 0.46s, accuracy: 96.46
# Epoch 29:	########################################	elapsed: 0.45s, accuracy: 96.59
# Epoch 30:	########################################	elapsed: 0.49s, accuracy: 96.57
# Epoch 31:	########################################	elapsed: 0.53s, accuracy: 96.59
# Epoch 32:	########################################	elapsed: 0.49s, accuracy: 96.65
# Epoch 33:	########################################	elapsed: 0.47s, accuracy: 96.67
# Epoch 34:	########################################	elapsed: 0.48s, accuracy: 96.67
# Epoch 35:	########################################	elapsed: 0.45s, accuracy: 96.64
# Epoch 36:	########################################	elapsed: 0.46s, accuracy: 96.65
# Epoch 37:	########################################	elapsed: 0.46s, accuracy: 96.63
# Epoch 38:	########################################	elapsed: 0.47s, accuracy: 96.61
# Epoch 39:	########################################	elapsed: 0.46s, accuracy: 96.63
# Epoch 40:	########################################	elapsed: 0.46s, accuracy: 96.64
# Epoch 41:	########################################	elapsed: 0.52s, accuracy: 96.63
# Epoch 42:	########################################	elapsed: 0.46s, accuracy: 96.64
# Epoch 43:	########################################	elapsed: 0.49s, accuracy: 96.64
# Epoch 44:	########################################	elapsed: 0.46s, accuracy: 96.63
# Epoch 45:	########################################	elapsed: 0.50s, accuracy: 96.64
# Epoch 46:	########################################	elapsed: 0.70s, accuracy: 96.65
# Epoch 47:	########################################	elapsed: 0.55s, accuracy: 96.65
# Epoch 48:	########################################	elapsed: 0.45s, accuracy: 96.65
# Epoch 49:	########################################	elapsed: 0.57s, accuracy: 96.66
# Epoch 50:	########################################	elapsed: 0.41s, accuracy: 96.66
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 0:	########################################	elapsed: 0.74s, reconstruction error: 79.32
# Epoch 1:	########################################	elapsed: 0.75s, reconstruction error: 56.68
# Epoch 2:	########################################	elapsed: 0.80s, reconstruction error: 43.93
# Epoch 3:	########################################	elapsed: 0.72s, reconstruction error: 37.69
# Epoch 4:	########################################	elapsed: 0.76s, reconstruction error: 33.82
# Epoch 5:	########################################	elapsed: 0.77s, reconstruction error: 25.96
# Epoch 6:	########################################	elapsed: 0.73s, reconstruction error: 22.68
# Epoch 7:	########################################	elapsed: 0.78s, reconstruction error: 20.54
# Epoch 8:	########################################	elapsed: 0.75s, reconstruction error: 19.01
# Epoch 9:	########################################	elapsed: 0.75s, reconstruction error: 17.91
# Epoch 10:	########################################	elapsed: 0.78s, reconstruction error: 17.54
# Epoch 11:	########################################	elapsed: 0.76s, reconstruction error: 16.46
# Epoch 12:	########################################	elapsed: 0.77s, reconstruction error: 16.18
# Epoch 13:	########################################	elapsed: 0.75s, reconstruction error: 15.54
# Epoch 14:	########################################	elapsed: 0.73s, reconstruction error: 14.92
# Epoch 15:	########################################	elapsed: 0.75s, reconstruction error: 14.55
# Epoch 16:	########################################	elapsed: 0.77s, reconstruction error: 14.23
# Epoch 17:	########################################	elapsed: 0.75s, reconstruction error: 13.91
# Epoch 18:	########################################	elapsed: 0.77s, reconstruction error: 13.70
# Epoch 19:	########################################	elapsed: 0.79s, reconstruction error: 13.33
# Epoch 20:	########################################	elapsed: 0.78s, reconstruction error: 13.29
# Epoch 21:	########################################	elapsed: 1.05s, reconstruction error: 13.31
# Epoch 22:	########################################	elapsed: 1.35s, reconstruction error: 12.93
# Epoch 23:	########################################	elapsed: 0.86s, reconstruction error: 12.81
# Epoch 24:	########################################	elapsed: 0.79s, reconstruction error: 12.62
# Epoch 25:	########################################	elapsed: 0.84s, reconstruction error: 12.37
# Epoch 26:	########################################	elapsed: 0.75s, reconstruction error: 12.56
# Epoch 27:	########################################	elapsed: 0.82s, reconstruction error: 12.41
# Epoch 28:	########################################	elapsed: 0.62s, reconstruction error: 12.33
# Epoch 29:	########################################	elapsed: 0.50s, reconstruction error: 12.14
# Epoch 30:	########################################	elapsed: 0.49s, reconstruction error: 12.14
# Epoch 31:	########################################	elapsed: 0.49s, reconstruction error: 12.10
# Epoch 32:	########################################	elapsed: 0.48s, reconstruction error: 12.03
# Epoch 33:	########################################	elapsed: 0.47s, reconstruction error: 12.11
# Epoch 34:	########################################	elapsed: 0.55s, reconstruction error: 11.89
# Epoch 35:	########################################	elapsed: 0.48s, reconstruction error: 11.90
# Epoch 36:	########################################	elapsed: 0.49s, reconstruction error: 11.76
# Epoch 37:	########################################	elapsed: 0.46s, reconstruction error: 11.85
# Epoch 38:	########################################	elapsed: 0.46s, reconstruction error: 11.65
# Epoch 39:	########################################	elapsed: 0.50s, reconstruction error: 11.71
# Epoch 40:	########################################	elapsed: 0.50s, reconstruction error: 11.78
# Epoch 41:	########################################	elapsed: 0.49s, reconstruction error: 11.79
# Epoch 42:	########################################	elapsed: 0.50s, reconstruction error: 11.77
# Epoch 43:	########################################	elapsed: 0.51s, reconstruction error: 11.73
# Epoch 44:	########################################	elapsed: 0.56s, reconstruction error: 11.88
# Epoch 45:	########################################	elapsed: 0.50s, reconstruction error: 11.73
# Epoch 46:	########################################	elapsed: 0.47s, reconstruction error: 11.59
# Epoch 47:	########################################	elapsed: 0.49s, reconstruction error: 11.65
# Epoch 48:	########################################	elapsed: 0.49s, reconstruction error: 11.88
# Epoch 49:	########################################	elapsed: 0.51s, reconstruction error: 11.55
#
# Learning layer 1
# Epoch 0:	########################################	elapsed: 0.35s, reconstruction error: 110.30
# Epoch 1:	########################################	elapsed: 0.36s, reconstruction error: 79.59
# Epoch 2:	########################################	elapsed: 0.35s, reconstruction error: 67.47
# Epoch 3:	########################################	elapsed: 0.37s, reconstruction error: 61.32
# Epoch 4:	########################################	elapsed: 0.34s, reconstruction error: 56.15
# Epoch 5:	########################################	elapsed: 0.35s, reconstruction error: 62.32
# Epoch 6:	########################################	elapsed: 0.35s, reconstruction error: 60.19
# Epoch 7:	########################################	elapsed: 0.39s, reconstruction error: 62.14
# Epoch 8:	########################################	elapsed: 0.35s, reconstruction error: 65.19
# Epoch 9:	########################################	elapsed: 0.34s, reconstruction error: 63.37
# Epoch 10:	########################################	elapsed: 0.35s, reconstruction error: 64.21
# Epoch 11:	########################################	elapsed: 0.36s, reconstruction error: 64.74
# Epoch 12:	########################################	elapsed: 0.34s, reconstruction error: 64.85
# Epoch 13:	########################################	elapsed: 0.35s, reconstruction error: 66.71
# Epoch 14:	########################################	elapsed: 0.37s, reconstruction error: 65.57
# Epoch 15:	########################################	elapsed: 0.54s, reconstruction error: 65.58
# Epoch 16:	########################################	elapsed: 0.41s, reconstruction error: 67.23
# Epoch 17:	########################################	elapsed: 0.34s, reconstruction error: 67.30
# Epoch 18:	########################################	elapsed: 0.33s, reconstruction error: 68.84
# Epoch 19:	########################################	elapsed: 0.34s, reconstruction error: 69.92
# Epoch 20:	########################################	elapsed: 0.35s, reconstruction error: 68.31
# Epoch 21:	########################################	elapsed: 0.40s, reconstruction error: 72.06
# Epoch 22:	########################################	elapsed: 0.33s, reconstruction error: 72.78
# Epoch 23:	########################################	elapsed: 0.34s, reconstruction error: 71.58
# Epoch 24:	########################################	elapsed: 0.34s, reconstruction error: 72.28
# Epoch 25:	########################################	elapsed: 0.35s, reconstruction error: 74.01
# Epoch 26:	########################################	elapsed: 0.36s, reconstruction error: 75.65
# Epoch 27:	########################################	elapsed: 0.36s, reconstruction error: 75.34
# Epoch 28:	########################################	elapsed: 0.35s, reconstruction error: 78.79
# Epoch 29:	########################################	elapsed: 0.35s, reconstruction error: 76.52
# Epoch 30:	########################################	elapsed: 0.35s, reconstruction error: 77.39
# Epoch 31:	########################################	elapsed: 0.36s, reconstruction error: 77.55
# Epoch 32:	########################################	elapsed: 0.35s, reconstruction error: 81.04
# Epoch 33:	########################################	elapsed: 0.35s, reconstruction error: 80.38
# Epoch 34:	########################################	elapsed: 0.38s, reconstruction error: 81.25
# Epoch 35:	########################################	elapsed: 0.40s, reconstruction error: 83.52
# Epoch 36:	########################################	elapsed: 0.51s, reconstruction error: 81.18
# Epoch 37:	########################################	elapsed: 0.32s, reconstruction error: 86.06
# Epoch 38:	########################################	elapsed: 0.35s, reconstruction error: 83.69
# Epoch 39:	########################################	elapsed: 0.35s, reconstruction error: 85.66
# Epoch 40:	########################################	elapsed: 0.34s, reconstruction error: 87.22
# Epoch 41:	########################################	elapsed: 0.34s, reconstruction error: 86.63
# Epoch 42:	########################################	elapsed: 0.36s, reconstruction error: 87.91
# Epoch 43:	########################################	elapsed: 0.34s, reconstruction error: 89.74
# Epoch 44:	########################################	elapsed: 0.34s, reconstruction error: 87.70
# Epoch 45:	########################################	elapsed: 0.34s, reconstruction error: 90.09
# Epoch 46:	########################################	elapsed: 0.34s, reconstruction error: 90.59
# Epoch 47:	########################################	elapsed: 0.35s, reconstruction error: 91.83
# Epoch 48:	########################################	elapsed: 0.35s, reconstruction error: 92.83
# Epoch 49:	########################################	elapsed: 0.37s, reconstruction error: 93.15
#
# Learning layer 2
# Epoch 0:	########################################	elapsed: 0.75s, reconstruction error: 100.67
# Epoch 1:	########################################	elapsed: 0.70s, reconstruction error: 77.06
# Epoch 2:	########################################	elapsed: 0.71s, reconstruction error: 65.18
# Epoch 3:	########################################	elapsed: 0.71s, reconstruction error: 57.54
# Epoch 4:	########################################	elapsed: 0.71s, reconstruction error: 52.22
# Epoch 5:	########################################	elapsed: 0.71s, reconstruction error: 40.51
# Epoch 6:	########################################	elapsed: 0.71s, reconstruction error: 36.20
# Epoch 7:	########################################	elapsed: 0.72s, reconstruction error: 33.46
# Epoch 8:	########################################	elapsed: 0.72s, reconstruction error: 32.71
# Epoch 9:	########################################	elapsed: 0.71s, reconstruction error: 32.39
# Epoch 10:	########################################	elapsed: 0.70s, reconstruction error: 31.73
# Epoch 11:	########################################	elapsed: 0.70s, reconstruction error: 31.71
# Epoch 12:	########################################	elapsed: 0.72s, reconstruction error: 31.52
# Epoch 13:	########################################	elapsed: 0.74s, reconstruction error: 30.97
# Epoch 14:	########################################	elapsed: 0.79s, reconstruction error: 31.68
# Epoch 15:	########################################	elapsed: 0.77s, reconstruction error: 32.28
# Epoch 16:	########################################	elapsed: 0.72s, reconstruction error: 31.16
# Epoch 17:	########################################	elapsed: 0.85s, reconstruction error: 32.42
# Epoch 18:	########################################	elapsed: 0.71s, reconstruction error: 32.69
# Epoch 19:	########################################	elapsed: 0.70s, reconstruction error: 33.23
# Epoch 20:	########################################	elapsed: 0.71s, reconstruction error: 32.82
# Epoch 21:	########################################	elapsed: 0.72s, reconstruction error: 32.66
# Epoch 22:	########################################	elapsed: 0.71s, reconstruction error: 33.44
# Epoch 23:	########################################	elapsed: 0.70s, reconstruction error: 33.26
# Epoch 24:	########################################	elapsed: 0.69s, reconstruction error: 33.13
# Epoch 25:	########################################	elapsed: 0.76s, reconstruction error: 33.62
# Epoch 26:	########################################	elapsed: 0.77s, reconstruction error: 34.23
# Epoch 27:	########################################	elapsed: 0.71s, reconstruction error: 35.66
# Epoch 28:	########################################	elapsed: 0.71s, reconstruction error: 34.82
# Epoch 29:	########################################	elapsed: 0.72s, reconstruction error: 35.23
# Epoch 30:	########################################	elapsed: 0.69s, reconstruction error: 36.68
# Epoch 31:	########################################	elapsed: 0.71s, reconstruction error: 34.92
# Epoch 32:	########################################	elapsed: 0.72s, reconstruction error: 34.75
# Epoch 33:	########################################	elapsed: 0.72s, reconstruction error: 34.36
# Epoch 34:	########################################	elapsed: 0.71s, reconstruction error: 35.59
# Epoch 35:	########################################	elapsed: 0.71s, reconstruction error: 35.83
# Epoch 36:	########################################	elapsed: 0.74s, reconstruction error: 36.23
# Epoch 37:	########################################	elapsed: 0.71s, reconstruction error: 36.24
# Epoch 38:	########################################	elapsed: 0.72s, reconstruction error: 35.76
# Epoch 39:	########################################	elapsed: 0.72s, reconstruction error: 36.86
# Epoch 40:	########################################	elapsed: 0.73s, reconstruction error: 37.64
# Epoch 41:	########################################	elapsed: 1.02s, reconstruction error: 37.34
# Epoch 42:	########################################	elapsed: 0.74s, reconstruction error: 36.63
# Epoch 43:	########################################	elapsed: 0.74s, reconstruction error: 38.16
# Epoch 44:	########################################	elapsed: 0.71s, reconstruction error: 35.99
# Epoch 45:	########################################	elapsed: 0.72s, reconstruction error: 36.46
# Epoch 46:	########################################	elapsed: 0.71s, reconstruction error: 38.33
# Epoch 47:	########################################	elapsed: 0.70s, reconstruction error: 38.61
# Epoch 48:	########################################	elapsed: 0.71s, reconstruction error: 37.50
# Epoch 49:	########################################	elapsed: 0.71s, reconstruction error: 38.09
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.70s, accuracy: 95.30
# Epoch 2:	########################################	elapsed: 0.40s, accuracy: 95.94
# Epoch 3:	########################################	elapsed: 0.38s, accuracy: 96.12
# Epoch 4:	########################################	elapsed: 0.45s, accuracy: 96.13
# Epoch 5:	########################################	elapsed: 0.46s, accuracy: 96.40
# Epoch 6:	########################################	elapsed: 0.40s, accuracy: 96.70
# Epoch 7:	########################################	elapsed: 0.43s, accuracy: 96.77
# Epoch 8:	########################################	elapsed: 0.43s, accuracy: 97.04
# Epoch 9:	########################################	elapsed: 0.38s, accuracy: 96.95
# Epoch 10:	########################################	elapsed: 0.41s, accuracy: 97.18
# Epoch 11:	########################################	elapsed: 0.41s, accuracy: 97.29
# Epoch 12:	########################################	elapsed: 0.43s, accuracy: 97.07
# Epoch 13:	########################################	elapsed: 0.38s, accuracy: 97.08
# Epoch 14:	########################################	elapsed: 0.42s, accuracy: 97.21
# Epoch 15:	########################################	elapsed: 0.40s, accuracy: 97.21
# Epoch 16:	########################################	elapsed: 0.38s, accuracy: 97.16
# Epoch 17:	########################################	elapsed: 0.38s, accuracy: 97.18
# Epoch 18:	########################################	elapsed: 0.40s, accuracy: 97.22
# Epoch 19:	########################################	elapsed: 0.42s, accuracy: 97.21
# Epoch 20:	########################################	elapsed: 0.43s, accuracy: 97.22
# Epoch 21:	########################################	elapsed: 0.50s, accuracy: 97.18
# Epoch 22:	########################################	elapsed: 0.52s, accuracy: 97.18
# Epoch 23:	########################################	elapsed: 0.42s, accuracy: 97.20
# Epoch 24:	########################################	elapsed: 0.46s, accuracy: 97.21
# Epoch 25:	########################################	elapsed: 0.39s, accuracy: 97.20
# Epoch 26:	########################################	elapsed: 0.43s, accuracy: 97.20
# Epoch 27:	########################################	elapsed: 0.43s, accuracy: 97.21
# Epoch 28:	########################################	elapsed: 0.44s, accuracy: 97.21
# Epoch 29:	########################################	elapsed: 0.46s, accuracy: 97.22
# Epoch 30:	########################################	elapsed: 0.40s, accuracy: 97.23
# Epoch 31:	########################################	elapsed: 0.39s, accuracy: 97.22
# Epoch 32:	########################################	elapsed: 0.50s, accuracy: 97.23
# Epoch 33:	########################################	elapsed: 0.44s, accuracy: 97.25
# Epoch 34:	########################################	elapsed: 0.40s, accuracy: 97.25
# Epoch 35:	########################################	elapsed: 0.42s, accuracy: 97.25
# Epoch 36:	########################################	elapsed: 0.40s, accuracy: 97.27
# Epoch 37:	########################################	elapsed: 0.42s, accuracy: 97.26
# Epoch 38:	########################################	elapsed: 0.43s, accuracy: 97.27
# Epoch 39:	########################################	elapsed: 0.44s, accuracy: 97.28
# Epoch 40:	########################################	elapsed: 0.44s, accuracy: 97.27
# Epoch 41:	########################################	elapsed: 0.43s, accuracy: 97.27
# Epoch 42:	########################################	elapsed: 0.56s, accuracy: 97.27
# Epoch 43:	########################################	elapsed: 0.51s, accuracy: 97.28
# Epoch 44:	########################################	elapsed: 0.45s, accuracy: 97.28
# Epoch 45:	########################################	elapsed: 0.42s, accuracy: 97.28
# Epoch 46:	########################################	elapsed: 0.41s, accuracy: 97.28
# Epoch 47:	########################################	elapsed: 0.44s, accuracy: 97.30
# Epoch 48:	########################################	elapsed: 0.42s, accuracy: 97.30
# Epoch 49:	########################################	elapsed: 0.58s, accuracy: 97.30
# Epoch 50:	########################################	elapsed: 0.43s, accuracy: 97.30
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
